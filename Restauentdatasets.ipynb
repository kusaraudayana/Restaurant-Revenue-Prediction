# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("D:\\Level 3\\Semester 2\\DS-3003 Machine Learning 1\\Project 3\\Datasets\\restaurant_data.csv",index_col='Name')
df.head()
# Out:
#               Location   Cuisine  Rating  Seating Capacity  \
# Name
# Restaurant 0     Rural  Japanese     4.0                38
# Restaurant 1  Downtown   Mexican     3.2                76
# Restaurant 2     Rural   Italian     4.7                48
# Restaurant 3     Rural   Italian     4.4                34
# Restaurant 4  Downtown  Japanese     4.9                88
#
#               Average Meal Price  Marketing Budget  Social Media Followers  \
# Name
# Restaurant 0               73.98              2224                   23406
# Restaurant 1               28.11              4416                   42741
# Restaurant 2               48.29              2796                   37285
# Restaurant 3               51.55              1167                   15214
# Restaurant 4               75.98              3639                   40171
#
#               Chef Experience Years  Number of Reviews  Avg Review Length  \
# Name
# ...

# %%
# A longer and higher-rated review may signal strong customer satisfaction.
df["Review Quality Score"] = df["Avg Review Length"] * df["Rating"]

# Price category
df["Meal Price Category"] = pd.cut(df["Average Meal Price"],
                                   bins=[0, 30, 60, 100],
                                   labels=["Low", "Medium", "High"])

# Drop unused/redundant columns
df.drop(columns=["Average Meal Price"], inplace=True)
df.drop(columns=["Avg Review Length"], inplace=True)
df.drop(columns=["Rating"], inplace=True)

# %%
# Define the new Cluster column based on Location
df['Cluster'] = df['Location'].apply(
    lambda x: 'Urban' if x == 'Downtown' else 'Nonurban' if x in ['Rural', 'Suburban'] else 'Other'
)

# %%
df.head()
# Out:
#               Location   Cuisine  Seating Capacity  Marketing Budget  \
# Name
# Restaurant 0     Rural  Japanese                38              2224
# Restaurant 1  Downtown   Mexican                76              4416
# Restaurant 2     Rural   Italian                48              2796
# Restaurant 3     Rural   Italian                34              1167
# Restaurant 4  Downtown  Japanese                88              3639
#
#               Social Media Followers  Chef Experience Years  \
# Name
# Restaurant 0                   23406                     13
# Restaurant 1                   42741                      8
# Restaurant 2                   37285                     18
# Restaurant 3                   15214                     13
# Restaurant 4                   40171                      9
#
#               Number of Reviews  Ambience Score  Service Quality Score  \
# Name
# Restaurant 0                185             1.3                    7.0
# ...

# %%
train_df, test_df = train_test_split(df, test_size=0.3, random_state=1000)

# %%
urban_train_df = train_df[train_df['Cluster'] == 'Urban'].copy()
urban_train_df.head()
# Out:
#                  Location   Cuisine  Seating Capacity  Marketing Budget  \
# Name
# Restaurant 5818  Downtown   Italian                90              5031
# Restaurant 808   Downtown    Indian                87              4113
# Restaurant 2853  Downtown   Italian                83              3941
# Restaurant 1744  Downtown   Mexican                78              2614
# Restaurant 2785  Downtown  American                77              1843
#
#                  Social Media Followers  Chef Experience Years  \
# Name
# Restaurant 5818                   58655                     13
# Restaurant 808                    44551                     14
# Restaurant 2853                   44981                     16
# Restaurant 1744                   26987                      3
# Restaurant 2785                   26233                     11
#
#                  Number of Reviews  Ambience Score  Service Quality Score  \
# Name
# ...

# %%
urban_train_df.shape
# Out:
# (1953, 16)

# %%
nonurban_train_df = train_df[train_df['Cluster'] == 'Nonurban'].copy()
nonurban_train_df.head()
# Out:
#                  Location   Cuisine  Seating Capacity  Marketing Budget  \
# Name
# Restaurant 1649     Rural  Japanese                49              3259
# Restaurant 1052  Suburban    Indian                55              2662
# Restaurant 2520  Suburban   Italian                60              1515
# Restaurant 1727     Rural   Italian                35              1778
# Restaurant 2717     Rural  Japanese                30              2966
#
#                  Social Media Followers  Chef Experience Years  \
# Name
# Restaurant 1649                   34243                      6
# Restaurant 1052                   34744                      4
# Restaurant 2520                   19829                     13
# Restaurant 1727                   24218                      1
# Restaurant 2717                   32413                      2
#
#                  Number of Reviews  Ambience Score  Service Quality Score  \
# Name
# ...

# %%
nonurban_train_df.shape
# Out:
# (3904, 16)

# %%
urban_test_df = test_df[test_df['Cluster'] == 'Urban'].copy()
urban_test_df.head()
# Out:
#                  Location   Cuisine  Seating Capacity  Marketing Budget  \
# Name
# Restaurant 7623  Downtown  Japanese                86              9065
# Restaurant 1029  Downtown   Mexican                89              1414
# Restaurant 2557  Downtown    French                77              2487
# Restaurant 2376  Downtown  Japanese                85              3459
# Restaurant 594   Downtown  Japanese                74              5519
#
#                  Social Media Followers  Chef Experience Years  \
# Name
# Restaurant 7623                   96518                     18
# Restaurant 1029                   20379                      4
# Restaurant 2557                   30116                      9
# Restaurant 2376                   42040                     13
# Restaurant 594                    63074                      3
#
#                  Number of Reviews  Ambience Score  Service Quality Score  \
# Name
# ...

# %%
urban_test_df.shape
# Out:
# (868, 16)

# %%
nonurban_test_df = test_df[test_df['Cluster'] == 'Nonurban'].copy()
nonurban_test_df.head()
# Out:
#                  Location   Cuisine  Seating Capacity  Marketing Budget  \
# Name
# Restaurant 7067  Suburban   Mexican                64              2695
# Restaurant 4801     Rural  American                33              2040
# Restaurant 2911     Rural  American                49              2137
# Restaurant 2244  Suburban   Italian                51              1304
# Restaurant 2507     Rural    French                32              1875
#
#                  Social Media Followers  Chef Experience Years  \
# Name
# Restaurant 7067                   33408                     13
# Restaurant 4801                   28686                     13
# Restaurant 2911                   23569                     18
# Restaurant 2244                   15045                     11
# Restaurant 2507                   18377                     14
#
#                  Number of Reviews  Ambience Score  Service Quality Score  \
# Name
# ...

# %%
nonurban_test_df.shape
# Out:
# (1643, 16)

# %%
#urban_train_df.to_csv('urban_train_df.csv', index=True)
#nonurban_train_df.to_csv('nonurban_train_df.csv', index=True)
#urban_test_df.to_csv('urban_test_df.csv', index=True)
#nonurban_test_df.to_csv('nonurban_test_df.csv', index=True)
